# %% [markdown]
# <a href="https://colab.research.google.com/github/somyamangla/WalmartAnalysis/blob/main/Walmart_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

# %%
import zipfile
# !unzip /content/zip.zip

# %%
import glob
File_paths = glob.glob('/content/zip.zip')

# %%
train_df=pd.read_csv('zip/train.csv')
test_df=pd.read_csv('zip/test.csv')
features_df=pd.read_csv('zip/features.csv')
stores_df=pd.read_csv('stores.csv')

# %%
train_df.head()
# Out:
#    Store  Dept        Date  Weekly_Sales  IsHoliday
# 0      1     1  2010-02-05      24924.50      False
# 1      1     1  2010-02-12      46039.49       True
# 2      1     1  2010-02-19      41595.55      False
# 3      1     1  2010-02-26      19403.54      False
# 4      1     1  2010-03-05      21827.90      False

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 421570 entries, 0 to 421569
# Data columns (total 5 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Store         421570 non-null  int64
#  1   Dept          421570 non-null  int64
#  2   Date          421570 non-null  object
#  3   Weekly_Sales  421570 non-null  float64
#  4   IsHoliday     421570 non-null  bool
# dtypes: bool(1), float64(1), int64(2), object(1)
# memory usage: 13.3+ MB

# %%
train_df.describe()
# Out:
#                Store           Dept   Weekly_Sales
# count  421570.000000  421570.000000  421570.000000
# mean       22.200546      44.260317   15981.258123
# std        12.785297      30.492054   22711.183519
# min         1.000000       1.000000   -4988.940000
# 25%        11.000000      18.000000    2079.650000
# 50%        22.000000      37.000000    7612.030000
# 75%        33.000000      74.000000   20205.852500
# max        45.000000      99.000000  693099.360000

# %%
train_df.isnull().sum()
# Out:
# Store           0
# Dept            0
# Date            0
# Weekly_Sales    0
# IsHoliday       0
# dtype: int64

# %%
test_df.head()
# Out:
#    Store  Dept        Date  IsHoliday
# 0      1     1  2012-11-02      False
# 1      1     1  2012-11-09      False
# 2      1     1  2012-11-16      False
# 3      1     1  2012-11-23       True
# 4      1     1  2012-11-30      False

# %%
test_df.describe()
# Out:
#                Store           Dept
# count  115064.000000  115064.000000
# mean       22.238207      44.339524
# std        12.809930      30.656410
# min         1.000000       1.000000
# 25%        11.000000      18.000000
# 50%        22.000000      37.000000
# 75%        33.000000      74.000000
# max        45.000000      99.000000

# %%
test_df.isnull().sum()
# Out:
# Store        0
# Dept         0
# Date         0
# IsHoliday    0
# dtype: int64

# %%
features_df.head()
# Out:
#    Store        Date  Temperature  ...         CPI  Unemployment  IsHoliday
# 0      1  2010-02-05        42.31  ...  211.096358         8.106      False
# 1      1  2010-02-12        38.51  ...  211.242170         8.106       True
# 2      1  2010-02-19        39.93  ...  211.289143         8.106      False
# 3      1  2010-02-26        46.63  ...  211.319643         8.106      False
# 4      1  2010-03-05        46.50  ...  211.350143         8.106      False
#
# [5 rows x 12 columns]

# %%
features_df.describe()
# Out:
#              Store  Temperature  ...          CPI  Unemployment
# count  8190.000000  8190.000000  ...  7605.000000   7605.000000
# mean     23.000000    59.356198  ...   172.460809      7.826821
# std      12.987966    18.678607  ...    39.738346      1.877259
# min       1.000000    -7.290000  ...   126.064000      3.684000
# 25%      12.000000    45.902500  ...   132.364839      6.634000
# 50%      23.000000    60.710000  ...   182.764003      7.806000
# 75%      34.000000    73.880000  ...   213.932412      8.567000
# max      45.000000   101.950000  ...   228.976456     14.313000
#
# [8 rows x 10 columns]

# %%
features_df.isnull().sum()
# Out:
# Store              0
# Date               0
# Temperature        0
# Fuel_Price         0
# MarkDown1       4158
# MarkDown2       5269
# MarkDown3       4577
# MarkDown4       4726
# MarkDown5       4140
# CPI              585
# Unemployment     585
# IsHoliday          0
# dtype: int64

# %%
stores_df.isnull().sum()
# Out:
# Store    0
# Type     0
# Size     0
# dtype: int64

# %%
#merging store and feature df
dataset_m=features_df.merge(stores_df,how="inner",on='Store')
dataset_m.head()
# Out:
#    Store        Date  Temperature  ...  IsHoliday  Type    Size
# 0      1  2010-02-05        42.31  ...      False     A  151315
# 1      1  2010-02-12        38.51  ...       True     A  151315
# 2      1  2010-02-19        39.93  ...      False     A  151315
# 3      1  2010-02-26        46.63  ...      False     A  151315
# 4      1  2010-03-05        46.50  ...      False     A  151315
#
# [5 rows x 14 columns]

# %%
dataset_m.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8190 entries, 0 to 8189
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Store         8190 non-null   int64
#  1   Date          8190 non-null   object
#  2   Temperature   8190 non-null   float64
#  3   Fuel_Price    8190 non-null   float64
#  4   MarkDown1     4032 non-null   float64
#  5   MarkDown2     2921 non-null   float64
#  6   MarkDown3     3613 non-null   float64
#  7   MarkDown4     3464 non-null   float64
#  8   MarkDown5     4050 non-null   float64
#  9   CPI           7605 non-null   float64
#  10  Unemployment  7605 non-null   float64
#  11  IsHoliday     8190 non-null   bool
#  12  Type          8190 non-null   object
#  13  Size          8190 non-null   int64
# dtypes: bool(1), float64(9), int64(2), object(2)
# memory usage: 903.8+ KB

# %%
from datetime import datetime

# %%
dataset_m['Date']=pd.to_datetime(dataset_m['Date'])
test_df['Date']=pd.to_datetime(test_df['Date'])
train_df['Date']=pd.to_datetime(train_df['Date'])

# %%
#getting week and year
dataset_m['week']=dataset_m.Date.dt.isocalendar().week
dataset_m['year']=dataset_m.Date.dt.isocalendar().year

# %%
dataset_m.tail()
# Out:
#       Store       Date  Temperature  Fuel_Price  ...  Type    Size  week  year
# 8185     45 2013-06-28        76.05       3.639  ...     B  118221    26  2013
# 8186     45 2013-07-05        77.50       3.614  ...     B  118221    27  2013
# 8187     45 2013-07-12        79.37       3.614  ...     B  118221    28  2013
# 8188     45 2013-07-19        82.84       3.737  ...     B  118221    29  2013
# 8189     45 2013-07-26        76.06       3.804  ...     B  118221    30  2013
#
# [5 rows x 16 columns]

# %%
#Creating a new df by merging (inner) the train_df and the new dataframe dataset_m on store, date and isholiday columns and sorting the values by store , department and date

# %%
train_df_1 = train_df.merge(dataset_m,how='inner', on=['Store','Date','IsHoliday']).sort_values(by=['Store','Dept','Date']).reset_index(drop=True)

# %%
 train_df_1
# Out:
#         Store  Dept       Date  Weekly_Sales  ...  Type    Size  week  year
# 0           1     1 2010-02-05      24924.50  ...     A  151315     5  2010
# 1           1     1 2010-02-12      46039.49  ...     A  151315     6  2010
# 2           1     1 2010-02-19      41595.55  ...     A  151315     7  2010
# 3           1     1 2010-02-26      19403.54  ...     A  151315     8  2010
# 4           1     1 2010-03-05      21827.90  ...     A  151315     9  2010
# ...       ...   ...        ...           ...  ...   ...     ...   ...   ...
# 421565     45    98 2012-09-28        508.37  ...     B  118221    39  2012
# 421566     45    98 2012-10-05        628.10  ...     B  118221    40  2012
# 421567     45    98 2012-10-12       1061.02  ...     B  118221    41  2012
# 421568     45    98 2012-10-19        760.01  ...     B  118221    42  2012
# 421569     45    98 2012-10-26       1076.80  ...     B  118221    43  2012
#
# [421570 rows x 18 columns]

# %% [markdown]
# visualisations

# %%
def scatter(train_df_1,column):
    #plot the figure
    plt.figure()
    #plot the scatter plot with data from the specified column in x axis and weekly sales in y axis
    plt.scatter(train_df_1[column],train_df_1['Weekly_Sales'])
    #give y label as weekly sales
    plt.ylabel('Weekly_Sales')
    #give the x label as the column specified as parameter in the function
    plt.xlabel(column)

# %%
scatter(train_df_1,'Store')

# %%
scatter(train_df_1,'Dept')

# %%
# Filtering out mean weekly sales for the year 2011
weekly_sales_2011 = train_df_1[train_df_1['year']==2011]['Weekly_Sales'].groupby(train_df_1['week']).mean()
#Plot a line plot with week on x axis and sales for that particular week of the filtered year in y axis
sns.lineplot(weekly_sales_2011.index,weekly_sales_2011.values,color='red')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
# Filtering out mean weekly sales for the year 2010
weekly_sales_2010 = train_df_1[train_df_1['year']==2010]['Weekly_Sales'].groupby(train_df_1['week']).mean()
#Plot a line plot with week on x axis and sales for that particular week of the filtered year in y axis
sns.lineplot(weekly_sales_2010.index,weekly_sales_2010.values,color='blue')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
# Filtering out mean weekly sales for the year 2012
weekly_sales_2012 = train_df_1[train_df_1['year']==2012]['Weekly_Sales'].groupby(train_df_1['week']).mean()
#Plot a line plot with week on x axis and sales for that particular week of the filtered year in y axis
sns.lineplot(weekly_sales_2012.index,weekly_sales_2012.values,color='green')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
#plotting a figure
plt.figure(figsize=(20,10))
#plotiing three line plots for weekly sales for each year
sns.lineplot(weekly_sales_2010.index,weekly_sales_2010.values,color='blue')
sns.lineplot(weekly_sales_2011.index,weekly_sales_2011.values,color='red')

sns.lineplot(weekly_sales_2012.index,weekly_sales_2012.values,color='green')
plt.grid()
#plot labels and legends
plt.xticks(np.arange(1,60,step=1))
plt.title('Average Weekly sales per year',fontsize=20)
plt.xlabel('week',fontsize=16)
plt.ylabel('sales',fontsize=16)
plt.legend(['2010','2011','2012'],fontsize=16)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.distplot(train_df_1['Weekly_Sales'],color='g')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
#Kurtosis is a measure of whether the data is heavy-tailed  or light-tailed relative to normal distribution
train_df_1['Weekly_Sales'].kurt()
# Out:
# 21.49128990832619

# %%
weekly_sales_store= train_df_1['Weekly_Sales'].groupby(train_df_1['Store']).mean()

# %%
weekly_sales_store.head()
# Out:
# Store
# 1    21710.543621
# 2    26898.070031
# 3     6373.033983
# 4    29161.210415
# 5     5053.415813
# Name: Weekly_Sales, dtype: float64

# %%
weekly_sales_store_df = pd.DataFrame(weekly_sales_store)

# %%
weekly_sales_store_df.sort_values('Weekly_Sales',ascending=False).style.bar(align='left',width=98,color='#FFD200')
# Out:
# <style  type="text/css" >
# #T_3b705a64_1899_11ec_9c7c_0242ac1c0002row0_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFD200 98.0%, transparent 98.0%);
#         }#T_3b705a64_1899_11ec_9c7c_0242ac1c0002row1_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFD200 96.6%, transparent 96.6%);
#         }#T_3b705a64_1899_11ec_9c7c_0242ac1c0002row2_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFD200 95.1%, transparent 95.1%);
#         }#T_3b705a64_1899_11ec_9c7c_0242ac1c0002row3_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFD200 89.4%, transparent 89.4%);
#         }#T_3b705a64_1899_11ec_9c7c_0242ac1c0002row4_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFD200 87.5%, transparent 87.5%);
#         }#T_3b705a64_1899_11ec_9c7c_0242ac1c0002row5_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFD200 85.3%, transparent 85.3%);
#         }#T_3b705a64_1899_11ec_9c7c_0242ac1c0002row6_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFD200 79.2%, transparent 79.2%);
#         }#T_3b705a64_1899_11ec_9c7c_0242ac1c0002row7_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFD200 67.6%, transparent 67.6%);
#         }#T_3b705a64_1899_11ec_9c7c_0242ac1c0002row8_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFD200 66.8%, transparent 66.8%);
#         }#T_3b705a64_1899_11ec_9c7c_0242ac1c0002row9_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFD200 63.9%, transparent 63.9%);
#         }#T_3b705a64_1899_11ec_9c7c_0242ac1c0002row10_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFD200 61.3%, transparent 61.3%);
#         }#T_3b705a64_1899_11ec_9c7c_0242ac1c0002row11_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFD200 59.0%, transparent 59.0%);
#         }#T_3b705a64_1899_11ec_9c7c_0242ac1c0002row12_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFD200 58.6%, transparent 58.6%);
#         }#T_3b705a64_1899_11ec_9c7c_0242ac1c0002row13_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFD200 57.0%, transparent 57.0%);
#         }#T_3b705a64_1899_11ec_9c7c_0242ac1c0002row14_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFD200 55.8%, transparent 55.8%);
#         }#T_3b705a64_1899_11ec_9c7c_0242ac1c0002row15_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFD200 54.7%, transparent 54.7%);
#         }#T_3b705a64_1899_11ec_9c7c_0242ac1c0002row16_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFD200 51.8%, transparent 51.8%);
#         }#T_3b705a64_1899_11ec_9c7c_0242ac1c0002row17_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFD200 45.3%, transparent 45.3%);
#         }#T_3b705a64_1899_11ec_9c7c_0242ac1c0002row18_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFD200 42.8%, transparent 42.8%);
#         }#T_3b705a64_1899_11ec_9c7c_0242ac1c0002row19_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFD200 40.6%, transparent 40.6%);
#         }#T_3b705a64_1899_11ec_9c7c_0242ac1c0002row20_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFD200 39.3%, transparent 39.3%);
#         }#T_3b705a64_1899_11ec_9c7c_0242ac1c0002row21_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFD200 38.1%, transparent 38.1%);
#         }#T_3b705a64_1899_11ec_9c7c_0242ac1c0002row22_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFD200 35.1%, transparent 35.1%);
#         }#T_3b705a64_1899_11ec_9c7c_0242ac1c0002row23_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFD200 34.9%, transparent 34.9%);
#         }#T_3b705a64_1899_11ec_9c7c_0242ac1c0002row24_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFD200 33.9%, transparent 33.9%);
#         }#T_3b705a64_1899_11ec_9c7c_0242ac1c0002row25_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFD200 33.5%, transparent 33.5%);
#         }#T_3b705a64_1899_11ec_9c7c_0242ac1c0002row26_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFD200 32.4%, transparent 32.4%);
#         }#T_3b705a64_1899_11ec_9c7c_0242ac1c0002row27_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFD200 31.7%, transparent 31.7%);
#         }#T_3b705a64_1899_11ec_9c7c_0242ac1c0002row28_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFD200 26.5%, transparent 26.5%);
#         }#T_3b705a64_1899_11ec_9c7c_0242ac1c0002row29_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFD200 25.6%, transparent 25.6%);
#         }#T_3b705a64_1899_11ec_9c7c_0242ac1c0002row30_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFD200 25.0%, transparent 25.0%);
#         }#T_3b705a64_1899_11ec_9c7c_0242ac1c0002row31_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFD200 21.1%, transparent 21.1%);
#         }#T_3b705a64_1899_11ec_9c7c_0242ac1c0002row32_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFD200 21.0%, transparent 21.0%);
#         }#T_3b705a64_1899_11ec_9c7c_0242ac1c0002row33_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFD200 15.8%, transparent 15.8%);
#         }#T_3b705a64_1899_11ec_9c7c_0242ac1c0002row34_col0,#T_3b705a64_1899_11ec_9c7c_0242ac1c0002row35_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFD200 14.9%, transparent 14.9%);
#         }#T_3b705a64_1899_11ec_9c7c_0242ac1c0002row36_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFD200 14.2%, transparent 14.2%);
#         }#T_3b705a64_1899_11ec_9c7c_0242ac1c0002row37_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFD200 13.2%, transparent 13.2%);
#         }#T_3b705a64_1899_11ec_9c7c_0242ac1c0002row38_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFD200 12.4%, transparent 12.4%);
#         }#T_3b705a64_1899_11ec_9c7c_0242ac1c0002row39_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFD200 11.3%, transparent 11.3%);
#         }#T_3b705a64_1899_11ec_9c7c_0242ac1c0002row40_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFD200 9.8%, transparent 9.8%);
#         }#T_3b705a64_1899_11ec_9c7c_0242ac1c0002row41_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-

# %%
weekly_sales_store_df.sort_values('Weekly_Sales').style.bar(align='left',width=98,color='#FFD200')
# Out:
# <style  type="text/css" >
# #T_43fea99c_1899_11ec_9c7c_0242ac1c0002row0_col0{
#             width:  10em;
#              height:  80%;
#         }#T_43fea99c_1899_11ec_9c7c_0242ac1c0002row1_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFD200 2.7%, transparent 2.7%);
#         }#T_43fea99c_1899_11ec_9c7c_0242ac1c0002row2_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFD200 3.9%, transparent 3.9%);
#         }#T_43fea99c_1899_11ec_9c7c_0242ac1c0002row3_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFD200 5.3%, transparent 5.3%);
#         }#T_43fea99c_1899_11ec_9c7c_0242ac1c0002row4_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFD200 9.8%, transparent 9.8%);
#         }#T_43fea99c_1899_11ec_9c7c_0242ac1c0002row5_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFD200 11.3%, transparent 11.3%);
#         }#T_43fea99c_1899_11ec_9c7c_0242ac1c0002row6_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFD200 12.4%, transparent 12.4%);
#         }#T_43fea99c_1899_11ec_9c7c_0242ac1c0002row7_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFD200 13.2%, transparent 13.2%);
#         }#T_43fea99c_1899_11ec_9c7c_0242ac1c0002row8_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFD200 14.2%, transparent 14.2%);
#         }#T_43fea99c_1899_11ec_9c7c_0242ac1c0002row9_col0,#T_43fea99c_1899_11ec_9c7c_0242ac1c0002row10_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFD200 14.9%, transparent 14.9%);
#         }#T_43fea99c_1899_11ec_9c7c_0242ac1c0002row11_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFD200 15.8%, transparent 15.8%);
#         }#T_43fea99c_1899_11ec_9c7c_0242ac1c0002row12_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFD200 21.0%, transparent 21.0%);
#         }#T_43fea99c_1899_11ec_9c7c_0242ac1c0002row13_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFD200 21.1%, transparent 21.1%);
#         }#T_43fea99c_1899_11ec_9c7c_0242ac1c0002row14_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFD200 25.0%, transparent 25.0%);
#         }#T_43fea99c_1899_11ec_9c7c_0242ac1c0002row15_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFD200 25.6%, transparent 25.6%);
#         }#T_43fea99c_1899_11ec_9c7c_0242ac1c0002row16_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFD200 26.5%, transparent 26.5%);
#         }#T_43fea99c_1899_11ec_9c7c_0242ac1c0002row17_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFD200 31.7%, transparent 31.7%);
#         }#T_43fea99c_1899_11ec_9c7c_0242ac1c0002row18_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFD200 32.4%, transparent 32.4%);
#         }#T_43fea99c_1899_11ec_9c7c_0242ac1c0002row19_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFD200 33.5%, transparent 33.5%);
#         }#T_43fea99c_1899_11ec_9c7c_0242ac1c0002row20_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFD200 33.9%, transparent 33.9%);
#         }#T_43fea99c_1899_11ec_9c7c_0242ac1c0002row21_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFD200 34.9%, transparent 34.9%);
#         }#T_43fea99c_1899_11ec_9c7c_0242ac1c0002row22_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFD200 35.1%, transparent 35.1%);
#         }#T_43fea99c_1899_11ec_9c7c_0242ac1c0002row23_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFD200 38.1%, transparent 38.1%);
#         }#T_43fea99c_1899_11ec_9c7c_0242ac1c0002row24_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFD200 39.3%, transparent 39.3%);
#         }#T_43fea99c_1899_11ec_9c7c_0242ac1c0002row25_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFD200 40.6%, transparent 40.6%);
#         }#T_43fea99c_1899_11ec_9c7c_0242ac1c0002row26_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFD200 42.8%, transparent 42.8%);
#         }#T_43fea99c_1899_11ec_9c7c_0242ac1c0002row27_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFD200 45.3%, transparent 45.3%);
#         }#T_43fea99c_1899_11ec_9c7c_0242ac1c0002row28_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFD200 51.8%, transparent 51.8%);
#         }#T_43fea99c_1899_11ec_9c7c_0242ac1c0002row29_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFD200 54.7%, transparent 54.7%);
#         }#T_43fea99c_1899_11ec_9c7c_0242ac1c0002row30_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFD200 55.8%, transparent 55.8%);
#         }#T_43fea99c_1899_11ec_9c7c_0242ac1c0002row31_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFD200 57.0%, transparent 57.0%);
#         }#T_43fea99c_1899_11ec_9c7c_0242ac1c0002row32_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFD200 58.6%, transparent 58.6%);
#         }#T_43fea99c_1899_11ec_9c7c_0242ac1c0002row33_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFD200 59.0%, transparent 59.0%);
#         }#T_43fea99c_1899_11ec_9c7c_0242ac1c0002row34_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFD200 61.3%, transparent 61.3%);
#         }#T_43fea99c_1899_11ec_9c7c_0242ac1c0002row35_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFD200 63.9%, transparent 63.9%);
#         }#T_43fea99c_1899_11ec_9c7c_0242ac1c0002row36_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFD200 66.8%, transparent 66.8%);
#         }#T_43fea99c_1899_11ec_9c7c_0242ac1c0002row37_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFD200 67.6%, transparent 67.6%);
#         }#T_43fea99c_1899_11ec_9c7c_0242ac1c0002row38_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFD200 79.2%, transparent 79.2%);
#         }#T_43fea99c_1899_11ec_9c7c_0242ac1c0002row39_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFD200 85.3%, transparent 85.3%);
#         }#T_43fea99c_1899_11ec_9c7c_0242ac1c0002row40_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFD200 87.5%, transparent 87.5%);
#         }#T_43fea99c_1899_11ec_9c7c_0242ac1c0002row41_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFD200 89.4%, transparent 89.4%);
#         }#T_43fea99c_1899_11ec_9c7c_02

# %%
#Ploting the figure
plt.figure(figsize=(25,12))
#create a barplot with stores in x axis and mean weekly sales as y value
sns.barplot(weekly_sales_store.index, weekly_sales_store.values, palette='dark')
plt.grid()
plt.title('Average weekly sales per store',fontsize=20)
plt.xlabel('store number',fontsize=16)
plt.ylabel('Sales per store',fontsize=16)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
weekly_sales_dept = train_df_1['Weekly_Sales'].groupby(train_df_1['Dept']).mean()

# %%
weekly_sales_dept_df=pd.DataFrame(weekly_sales_dept)

# %%
weekly_sales_dept_df.head()
# Out:
#       Weekly_Sales
# Dept
# 1     19213.485088
# 2     43607.020113
# 3     11793.698516
# 4     25974.630238
# 5     21365.583515

# %%
# sorting the dataframe with respect to weekly sales in Descending order 
weekly_sales_dept_df.sort_values("Weekly_Sales",ascending=False).style.bar(align='left',width=98)
# Out:
# <style  type="text/css" >
# #T_7bc6c148_1899_11ec_9c7c_0242ac1c0002row0_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 98.0%, transparent 98.0%);
#         }#T_7bc6c148_1899_11ec_9c7c_0242ac1c0002row1_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 91.0%, transparent 91.0%);
#         }#T_7bc6c148_1899_11ec_9c7c_0242ac1c0002row2_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 79.6%, transparent 79.6%);
#         }#T_7bc6c148_1899_11ec_9c7c_0242ac1c0002row3_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 65.9%, transparent 65.9%);
#         }#T_7bc6c148_1899_11ec_9c7c_0242ac1c0002row4_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 59.2%, transparent 59.2%);
#         }#T_7bc6c148_1899_11ec_9c7c_0242ac1c0002row5_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 58.9%, transparent 58.9%);
#         }#T_7bc6c148_1899_11ec_9c7c_0242ac1c0002row6_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 58.5%, transparent 58.5%);
#         }#T_7bc6c148_1899_11ec_9c7c_0242ac1c0002row7_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 56.8%, transparent 56.8%);
#         }#T_7bc6c148_1899_11ec_9c7c_0242ac1c0002row8_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 43.9%, transparent 43.9%);
#         }#T_7bc6c148_1899_11ec_9c7c_0242ac1c0002row9_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 43.5%, transparent 43.5%);
#         }#T_7bc6c148_1899_11ec_9c7c_0242ac1c0002row10_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 40.0%, transparent 40.0%);
#         }#T_7bc6c148_1899_11ec_9c7c_0242ac1c0002row11_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 39.3%, transparent 39.3%);
#         }#T_7bc6c148_1899_11ec_9c7c_0242ac1c0002row12_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 35.2%, transparent 35.2%);
#         }#T_7bc6c148_1899_11ec_9c7c_0242ac1c0002row13_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 33.9%, transparent 33.9%);
#         }#T_7bc6c148_1899_11ec_9c7c_0242ac1c0002row14_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 31.5%, transparent 31.5%);
#         }#T_7bc6c148_1899_11ec_9c7c_0242ac1c0002row15_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 31.2%, transparent 31.2%);
#         }#T_7bc6c148_1899_11ec_9c7c_0242ac1c0002row16_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 28.6%, transparent 28.6%);
#         }#T_7bc6c148_1899_11ec_9c7c_0242ac1c0002row17_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 27.8%, transparent 27.8%);
#         }#T_7bc6c148_1899_11ec_9c7c_0242ac1c0002row18_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 26.3%, transparent 26.3%);
#         }#T_7bc6c148_1899_11ec_9c7c_0242ac1c0002row19_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 26.0%, transparent 26.0%);
#         }#T_7bc6c148_1899_11ec_9c7c_0242ac1c0002row20_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 25.0%, transparent 25.0%);
#         }#T_7bc6c148_1899_11ec_9c7c_0242ac1c0002row21_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 23.9%, transparent 23.9%);
#         }#T_7bc6c148_1899_11ec_9c7c_0242ac1c0002row22_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 20.4%, transparent 20.4%);
#         }#T_7bc6c148_1899_11ec_9c7c_0242ac1c0002row23_col0,#T_7bc6c148_1899_11ec_9c7c_0242ac1c0002row24_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 20.2%, transparent 20.2%);
#         }#T_7bc6c148_1899_11ec_9c7c_0242ac1c0002row25_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 19.8%, transparent 19.8%);
#         }#T_7bc6c148_1899_11ec_9c7c_0242ac1c0002row26_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 19.4%, transparent 19.4%);
#         }#T_7bc6c148_1899_11ec_9c7c_0242ac1c0002row27_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 18.9%, transparent 18.9%);
#         }#T_7bc6c148_1899_11ec_9c7c_0242ac1c0002row28_col0,#T_7bc6c148_1899_11ec_9c7c_0242ac1c0002row29_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 18.6%, transparent 18.6%);
#         }#T_7bc6c148_1899_11ec_9c7c_0242ac1c0002row30_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 18.0%, transparent 18.0%);
#         }#T_7bc6c148_1899_11ec_9c7c_0242ac1c0002row31_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 17.5%, transparent 17.5%);
#         }#T_7bc6c148_1899_11ec_9c7c_0242ac1c0002row32_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 15.9%, transparent 15.9%);
#         }#T_7bc6c148_1899_11ec_9c7c_0242ac1c0002row33_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 15.4%, transparent 15.4%);
#         }#T_7bc6c148_1899_11ec_9c7c_0242ac1c0002row34_col0,#T_7bc6c148_1899_11ec_9c7c_0242ac1c0002row35_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 14.0%, transparent 14.0%);
#         }#T_7bc6c148_1899_11ec_9c7c_0242ac1c0002row36_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 13.3%, transparent 13.3%);
#         }#T_7bc6c148_1899_11ec_9c7c_0242ac1c0002row37_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 11.7%, transparent 11.7%);
#         }#T_7bc6c148_1899_11ec_9c7c_0242ac1c0002row38_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 10.6%, transparent 10.6%);
#         }#T_7bc6c148_1899_11ec_9c7c_0242ac1c0002row39_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 10.0%, transparent 10.0%);
#         }#T_7bc6c148_1899_11ec_9c7c_0242ac1c0002row40_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 9.7%, transparent 9.7%);
#         }#T_7bc6c148_1899_11ec_9c7c_0242ac1c0002row41_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 9.6%, transparent 9.6%);
#         }#T_7bc6c148_1899_11ec_9c7c_0242ac1c0002row42_col0,#T_7bc6c148_1899_11ec_9c7c_0242ac1c0002row43_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 8.9%, transparent 8.9%);

# %%
#ploting a figure
plt.figure(figsize=(25,12))
#create a bar plot with department in x axis and mean weekly sales for each store as y values.
sns.barplot(weekly_sales_dept.index,weekly_sales_dept.values)
plt.grid()
plt.title('Average weekly sales per department',fontsize=20)
plt.xlabel('Department')
plt.ylabel('avg sales')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
#plotting the normal distribution where sales is greater than zero
train_sales = train_df_1[train_df_1['Weekly_Sales']>0]

train_lessthanzero= train_df_1[train_df_1['Weekly_Sales']<=0]
# Take natural log of data for sales more than zero
salesgreaterthanzero = np.log1p(train_sales['Weekly_Sales'])
sns.distplot(salesgreaterthanzero)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
## 12) Heatmap
plt.figure(figsize=(25,15))
sns.heatmap(train_df_1.corr(),annot=True)
